# %% [markdown]
# <a href="https://colab.research.google.com/github/abhiWriteCode/basic-GANs/blob/master/3%20-%20Auxiliary%20Classifier%20GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [code](https://keras.io/examples/mnist_acgan/)

# %%
from collections import defaultdict
try:
    import cPickle as pickle
except ImportError:
    import pickle
from PIL import Image

from six.moves import range

from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers
from tensorflow.keras.layers import (Input, Dense, Reshape, Flatten, Embedding, 
                                     Dropout, BatchNormalization, LeakyReLU, 
                                     Conv2DTranspose, Conv2D)
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
from keras.utils.generic_utils import Progbar
import numpy as np

np.random.seed(1337)
num_classes = 10

import tensorflow as tf
import keras

print(tf.__version__, keras.__version__)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# 1.15.0 2.2.5
# Using TensorFlow backend.

# %%
def build_generator(latent_size):
    # we will map a pair of (z, L), where z is a latent vector and L is a
    # label drawn from P_c, to image space (..., 28, 28, 1)
    cnn = Sequential()

    cnn.add(Dense(3 * 3 * 384, input_dim=latent_size, activation='relu'))
    cnn.add(Reshape((3, 3, 384)))

    # upsample to (7, 7, ...)
    cnn.add(Conv2DTranspose(192, 5, strides=1, padding='valid',
                            activation='relu',
                            kernel_initializer='glorot_normal'))
    cnn.add(BatchNormalization())

    # upsample to (14, 14, ...)
    cnn.add(Conv2DTranspose(96, 5, strides=2, padding='same',
                            activation='relu',
                            kernel_initializer='glorot_normal'))
    cnn.add(BatchNormalization())

    # upsample to (28, 28, ...)
    cnn.add(Conv2DTranspose(1, 5, strides=2, padding='same',
                            activation='tanh',
                            kernel_initializer='glorot_normal'))

    # this is the z space commonly referred to in GAN papers
    latent = Input(shape=(latent_size, ))

    # this will be our label
    image_class = Input(shape=(1,), dtype='int32')

    cls = Embedding(num_classes, latent_size,
                    embeddings_initializer='glorot_normal')(image_class)

    # hadamard product between z-space and a class conditional embedding
    h = layers.multiply([latent, cls])

    fake_image = cnn(h)

    return Model([latent, image_class], fake_image)

# %%
def build_discriminator():
    # build a relatively standard conv net, with LeakyReLUs as suggested in
    # the reference paper
    cnn = Sequential()

    cnn.add(Conv2D(32, 3, padding='same', strides=2,
                   input_shape=(28, 28, 1)))
    cnn.add(LeakyReLU(0.2))
    cnn.add(Dropout(0.3))

    cnn.add(Conv2D(64, 3, padding='same', strides=1))
    cnn.add(LeakyReLU(0.2))
    cnn.add(Dropout(0.3))

    cnn.add(Conv2D(128, 3, padding='same', strides=2))
    cnn.add(LeakyReLU(0.2))
    cnn.add(Dropout(0.3))

    cnn.add(Conv2D(256, 3, padding='same', strides=1))
    cnn.add(LeakyReLU(0.2))
    cnn.add(Dropout(0.3))

    cnn.add(Flatten())

    image = Input(shape=(28, 28, 1))

    features = cnn(image)

    # first output (name=generation) is whether or not the discriminator
    # thinks the image that is being shown is fake, and the second output
    # (name=auxiliary) is the class that the discriminator thinks the image
    # belongs to.
    fake = Dense(1, activation='sigmoid', name='generation')(features)
    aux = Dense(num_classes, activation='softmax', name='auxiliary')(features)

    return Model(image, [fake, aux])

# %%
# batch and latent size taken from the paper
epochs = 100
batch_size = 100
latent_size = 100

# Adam parameters suggested in https://arxiv.org/abs/1511.06434
adam_lr = 0.0002
adam_beta_1 = 0.5

# build the discriminator
print('Discriminator model:')
discriminator = build_discriminator()
discriminator.compile(
    optimizer=Adam(lr=adam_lr, beta_1=adam_beta_1),
    loss=['binary_crossentropy', 'sparse_categorical_crossentropy']
)
discriminator.summary()

# build the generator
generator = build_generator(latent_size)

latent = Input(shape=(latent_size, ))
image_class = Input(shape=(1,), dtype='int32')

# get a fake image
fake = generator([latent, image_class])

# we only want to be able to train generation for the combined model
discriminator.trainable = False
fake, aux = discriminator(fake)
combined = Model([latent, image_class], [fake, aux])

print('Combined model:')
combined.compile(
    optimizer=Adam(lr=adam_lr, beta_1=adam_beta_1),
    loss=['binary_crossentropy', 'sparse_categorical_crossentropy']
)

combined.summary()
# Out:
# Discriminator model:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 12544)        387840      input_1[0][0]
# __________________________________________________________________________________________________
# generation (Dense)              (None, 1)            12545       sequential[1][0]
# __________________________________________________________________________________________________
# auxiliary (Dense)               (None, 10)           125450      sequential[1][0]
# ==================================================================================================
# Total params: 525,835
# Trainable params: 525,835
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Combined model:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# model_1 (Model)                 (None, 28, 28, 1)    2657897     input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# model (Model)                   [(None, 1), (None, 1 525835      model_1[1][0]
# ==================================================================================================
# Total params: 3,183,732
# Trainable params: 2,657,321
# Non-trainable params: 526,411
# __________________________________________________________________________________________________

# %%
# get our mnist data, and force it to be of shape (..., 28, 28, 1) with
# range [-1, 1]
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = (x_train.astype(np.float32) - 127.5) / 127.5
x_train = np.expand_dims(x_train, axis=-1)

x_test = (x_test.astype(np.float32) - 127.5) / 127.5
x_test = np.expand_dims(x_test, axis=-1)

num_train, num_test = x_train.shape[0], x_test.shape[0]

train_history = defaultdict(list)
test_history = defaultdict(list)

# %%
try:
    for epoch in range(1, epochs + 1):
        print('Epoch {}/{}'.format(epoch, epochs))

        num_batches = int(np.ceil(x_train.shape[0] / float(batch_size)))
        progress_bar = Progbar(target=num_batches)

        epoch_gen_loss = []
        epoch_disc_loss = []

        for index in range(num_batches):
            # get a batch of real images
            image_batch = x_train[index * batch_size:(index + 1) * batch_size]
            label_batch = y_train[index * batch_size:(index + 1) * batch_size]

            # generate a new batch of noise
            noise = np.random.uniform(-1, 1, (len(image_batch), latent_size))

            # sample some labels from p_c
            sampled_labels = np.random.randint(0, num_classes, len(image_batch))

            # generate a batch of fake images, using the generated labels as a
            # conditioner. We reshape the sampled labels to be
            # (len(image_batch), 1) so that we can feed them into the embedding
            # layer as a length one sequence
            generated_images = generator.predict(
                [noise, sampled_labels.reshape((-1, 1))], verbose=0)

            x = np.concatenate((image_batch, generated_images))

            # use one-sided soft real/fake labels
            # Salimans et al., 2016
            # https://arxiv.org/pdf/1606.03498.pdf (Section 3.4)
            soft_zero, soft_one = 0, 0.95
            y = np.array(
                [soft_one] * len(image_batch) + [soft_zero] * len(image_batch))
            aux_y = np.concatenate((label_batch, sampled_labels), axis=0)

            # we don't want the discriminator to also maximize the classification
            # accuracy of the auxiliary classifier on generated images, so we
            # don't train discriminator to produce class labels for generated
            # images (see https://openreview.net/forum?id=rJXTf9Bxg).
            # To preserve sum of sample weights for the auxiliary classifier,
            # we assign sample weight of 2 to the real images.
            disc_sample_weight = [np.ones(2 * len(image_batch)),
                                  np.concatenate((np.ones(len(image_batch)) * 2,
                                                  np.zeros(len(image_batch))))]

            # see if the discriminator can figure itself out...
            epoch_disc_loss.append(discriminator.train_on_batch(
                x, [y, aux_y], sample_weight=disc_sample_weight))

            # make new noise. we generate 2 * batch size here such that we have
            # the generator optimize over an identical number of images as the
            # discriminator
            noise = np.random.uniform(-1, 1, (2 * len(image_batch), latent_size))
            sampled_labels = np.random.randint(0, num_classes, 2 * len(image_batch))

            # we want to train the generator to trick the discriminator
            # For the generator, we want all the {fake, not-fake} labels to say
            # not-fake
            trick = np.ones(2 * len(image_batch)) * soft_one

            epoch_gen_loss.append(combined.train_on_batch(
                [noise, sampled_labels.reshape((-1, 1))],
                [trick, sampled_labels]))

            progress_bar.update(index + 1)

        print('Testing for epoch {}:'.format(epoch))

        # evaluate the testing loss here

        # generate a new batch of noise
        noise = np.random.uniform(-1, 1, (num_test, latent_size))

        # sample some labels from p_c and generate images from them
        sampled_labels = np.random.randint(0, num_classes, num_test)
        generated_images = generator.predict(
            [noise, sampled_labels.reshape((-1, 1))], verbose=False)

        x = np.concatenate((x_test, generated_images))
        y = np.array([1] * num_test + [0] * num_test)
        aux_y = np.concatenate((y_test, sampled_labels), axis=0)

        # see if the discriminator can figure itself out...
        discriminator_test_loss = discriminator.evaluate(
            x, [y, aux_y], verbose=False)

        discriminator_train_loss = np.mean(np.array(epoch_disc_loss), axis=0)

        # make new noise
        noise = np.random.uniform(-1, 1, (2 * num_test, latent_size))
        sampled_labels = np.random.randint(0, num_classes, 2 * num_test)

        trick = np.ones(2 * num_test)

        generator_test_loss = combined.evaluate(
            [noise, sampled_labels.reshape((-1, 1))],
            [trick, sampled_labels], verbose=False)

        generator_train_loss = np.mean(np.array(epoch_gen_loss), axis=0)

        # generate an epoch report on performance
        train_history['generator'].append(generator_train_loss)
        train_history['discriminator'].append(discriminator_train_loss)

        test_history['generator'].append(generator_test_loss)
        test_history['discriminator'].append(discriminator_test_loss)

        print('{0:<22s} | {1:4s} | {2:15s} | {3:5s}'.format(
            'component', *discriminator.metrics_names))
        print('-' * 65)

        ROW_FMT = '{0:<22s} | {1:<4.2f} | {2:<15.4f} | {3:<5.4f}'
        print(ROW_FMT.format('generator (train)',
                             *train_history['generator'][-1]))
        print(ROW_FMT.format('generator (test)',
                             *test_history['generator'][-1]))
        print(ROW_FMT.format('discriminator (train)',
                             *train_history['discriminator'][-1]))
        print(ROW_FMT.format('discriminator (test)',
                             *test_history['discriminator'][-1]))

        # save weights every epoch
        generator.save_weights(
            'params_generator_epoch_{0:03d}.hdf5'.format(epoch), True)
        discriminator.save_weights(
            'params_discriminator_epoch_{0:03d}.hdf5'.format(epoch), True)

        # generate some digits to display
        num_rows = 40
        noise = np.tile(np.random.uniform(-1, 1, (num_rows, latent_size)),
                        (num_classes, 1))

        sampled_labels = np.array([
            [i] * num_rows for i in range(num_classes)
        ]).reshape(-1, 1)

        # get a batch to display
        generated_images = generator.predict(
            [noise, sampled_labels], verbose=0)

        # prepare real images sorted by class label
        real_labels = y_train[(epoch - 1) * num_rows * num_classes:
                              epoch * num_rows * num_classes]
        indices = np.argsort(real_labels, axis=0)
        real_images = x_train[(epoch - 1) * num_rows * num_classes:
                              epoch * num_rows * num_classes][indices]

        # display generated images, white separator, real images
        img = np.concatenate(
            (generated_images,
             np.repeat(np.ones_like(x_train[:1]), num_rows, axis=0),
             real_images))

        # arrange them into a grid
        img = (np.concatenate([r.reshape(-1, 28)
                               for r in np.split(img, 2 * num_classes + 1)
                               ], axis=-1) * 127.5 + 127.5).astype(np.uint8)

        Image.fromarray(img).save(
            'plot_epoch_{0:03d}_generated.png'.format(epoch))

    with open('acgan-history.pkl', 'wb') as f:
        pickle.dump({'train': train_history, 'test': test_history}, f)
except KeyboardInterrupt:
    print('\n\n\tStoped\n')
# Out:
# Epoch 1/100
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# 600/600 [==============================] - 37s 62ms/step
# Testing for epoch 1:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 1.06 | 0.6082          | 0.4493
# generator (test)       | 0.75 | 0.5594          | 0.1931
# discriminator (train)  | 0.62 | 0.2006          | 0.4227
# discriminator (test)   | 0.79 | 0.6086          | 0.1812
# Epoch 2/100
# 600/600 [==============================] - 33s 55ms/step
# Testing for epoch 2:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 1.11 | 1.0537          | 0.0519
# generator (test)       | 1.03 | 1.0157          | 0.0162
# discriminator (train)  | 0.81 | 0.6463          | 0.1618
# discriminator (test)   | 0.77 | 0.7171          | 0.0556
# Epoch 3/100
# 600/600 [==============================] - 33s 55ms/step
# Testing for epoch 3:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.84 | 0.8251          | 0.0169
# generator (test)       | 0.73 | 0.7203          | 0.0056
# discriminator (train)  | 0.81 | 0.7009          | 0.1113
# discriminator (test)   | 0.77 | 0.7296          | 0.0367
# Epoch 4/100
# 600/600 [==============================] - 33s 55ms/step
# Testing for epoch 4:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.81 | 0.8007          | 0.0111
# generator (test)       | 0.80 | 0.7953          | 0.0045
# discriminator (train)  | 0.80 | 0.7077          | 0.0897
# discriminator (test)   | 0.75 | 0.7236          | 0.0302
# Epoch 5/100
# 600/600 [==============================] - 33s 55ms/step
# Testing for epoch 5:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.80 | 0.7874          | 0.0087
# generator (test)       | 0.78 | 0.7759          | 0.0028
# discriminator (train)  | 0.78 | 0.7061          | 0.0781
# discriminator (test)   | 0.73 | 0.7035          | 0.0252
# Epoch 6/100
# 600/600 [==============================] - 33s 55ms/step
# Testing for epoch 6:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.79 | 0.7846          | 0.0067
# generator (test)       | 0.85 | 0.8524          | 0.0024
# discriminator (train)  | 0.77 | 0.7039          | 0.0677
# discriminator (test)   | 0.74 | 0.7161          | 0.0221
# Epoch 7/100
# 600/600 [==============================] - 33s 55ms/step
# Testing for epoch 7:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.79 | 0.7830          | 0.0063
# generator (test)       | 0.77 | 0.7682          | 0.0021
# discriminator (train)  | 0.76 | 0.7032          | 0.0610
# discriminator (test)   | 0.75 | 0.7310          | 0.0198
# Epoch 8/100
# 600/600 [==============================] - 33s 55ms/step
# Testing for epoch 8:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7784          | 0.0060
# generator (test)       | 0.80 | 0.8008          | 0.0012
# discriminator (train)  | 0.76 | 0.7029          | 0.0549
# discriminator (test)   | 0.73 | 0.7110          | 0.0181
# Epoch 9/100
# 600/600 [==============================] - 33s 55ms/step
# Testing for epoch 9:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7737          | 0.0050
# generator (test)       | 0.78 | 0.7825          | 0.0010
# discriminator (train)  | 0.75 | 0.7008          | 0.0497
# discriminator (test)   | 0.74 | 0.7234          | 0.0164
# Epoch 10/100
# 600/600 [==============================] - 33s 55ms/step
# Testing for epoch 10:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7719          | 0.0047
# generator (test)       | 0.81 | 0.8077          | 0.0008
# discriminator (train)  | 0.75 | 0.7010          | 0.0502
# discriminator (test)   | 0.76 | 0.7420          | 0.0158
# Epoch 11/100
# 600/600 [==============================] - 33s 55ms/step
# Testing for epoch 11:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7677          | 0.0043
# generator (test)       | 0.80 | 0.7995          | 0.0007
# discriminator (train)  | 0.74 | 0.7000          | 0.0440
# discriminator (test)   | 0.74 | 0.7260          | 0.0143
# Epoch 12/100
# 600/600 [==============================] - 33s 55ms/step
# Testing for epoch 12:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7662          | 0.0038
# generator (test)       | 0.81 | 0.8043          | 0.0011
# discriminator (train)  | 0.74 | 0.7004          | 0.0421
# discriminator (test)   | 0.74 | 0.7252          | 0.0141
# Epoch 13/100
# 600/600 [==============================] - 33s 56ms/step
# Testing for epoch 13:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7627          | 0.0041
# generator (test)       | 0.77 | 0.7741          | 0.0007
# discriminator (train)  | 0.74 | 0.6994          | 0.0398
# discriminator (test)   | 0.75 | 0.7394          | 0.0133
# Epoch 14/100
# 600/600 [==============================] - 33s 55ms/step
# Testing for epoch 14:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7631          | 0.0033
# generator (test)       | 0.82 | 0.8212          | 0.0004
# discriminator (train)  | 0.74 | 0.6994          | 0.0372
# discriminator (test)   | 0.74 | 0.7315          | 0.0127
# Epoch 15/100
# 600/600 [==============================] - 33s 56ms/step
# Testing for epoch 15:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7641          | 0.0029
# generator (test)       | 0.79 | 0.7896          | 0.0008
# discriminator (train)  | 0.73 | 0.6994          | 0.0348
# discriminator (test)   | 0.74 | 0.7266          | 0.0125
# Epoch 16/100
# 600/600 [==============================] - 34s 56ms/step
# Testing for epoch 16:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7622          | 0.0028
# generator (test)       | 0.79 | 0.7827          | 0.0025
# discriminator (train)  | 0.73 | 0.6984          | 0.0336
# discriminator (test)   | 0.73 | 0.7173          | 0.0134
# Epoch 17/100
# 600/600 [==============================] - 33s 55ms/step
# Testing for epoch 17:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7627          | 0.0030
# generator (test)       | 0.77 | 0.7688          | 0.0005
# discriminator (train)  | 0.73 | 0.6975          | 0.0308
# discriminator (test)   | 0.76 | 0.7485          | 0.0124
# Epoch 18/100
# 600/600 [==============================] - 34s 56ms/step
# Testing for epoch 18:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7639          | 0.0026
# generator (test)       | 0.80 | 0.8041          | 0.0003
# discriminator (train)  | 0.73 | 0.6979          | 0.0307
# discriminator (test)   | 0.74 | 0.7292          | 0.0121
# Epoch 19/100
# 600/600 [==============================] - 34s 57ms/step
# Testing for epoch 19:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7636          | 0.0024
# generator (test)       | 0.80 | 0.7991          | 0.0002
# discriminator (train)  | 0.73 | 0.6961          | 0.0297
# discriminator (test)   | 0.75 | 0.7408          | 0.0121
# Epoch 20/100
# 600/600 [==============================] - 34s 57ms/step
# Testing for epoch 20:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7642          | 0.0027
# generator (test)       | 0.79 | 0.7926          | 0.0001
# discriminator (train)  | 0.72 | 0.6950          | 0.0292
# discriminator (test)   | 0.73 | 0.7148          | 0.0113
# Epoch 21/100
# 600/600 [==============================] - 34s 56ms/step
# Testing for epoch 21:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7650          | 0.0029
# generator (test)       | 0.82 | 0.8208          | 0.0003
# discriminator (train)  | 0.72 | 0.6941          | 0.0288
# discriminator (test)   | 0.76 | 0.7478          | 0.0115
# Epoch 22/100
# 600/600 [==============================] - 34s 57ms/step
# Testing for epoch 22:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7674          | 0.0022
# generator (test)       | 0.78 | 0.7842          | 0.0006
# discriminator (train)  | 0.72 | 0.6956          | 0.0258
# discriminator (test)   | 0.73 | 0.7228          | 0.0113
# Epoch 23/100
# 600/600 [==============================] - 34s 57ms/step
# Testing for epoch 23:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7662          | 0.0025
# generator (test)       | 0.82 | 0.8219          | 0.0003
# discriminator (train)  | 0.72 | 0.6928          | 0.0261
# discriminator (test)   | 0.73 | 0.7132          | 0.0120
# Epoch 24/100
# 600/600 [==============================] - 35s 59ms/step
# Testing for epoch 24:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7716          | 0.0024
# generator (test)       | 0.77 | 0.7672          | 0.0001
# discriminator (train)  | 0.72 | 0.6933          | 0.0256
# discriminator (test)   | 0.71 | 0.7003          | 0.0126
# Epoch 25/100
# 600/600 [==============================] - 35s 58ms/step
# Testing for epoch 25:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7737          | 0.0025
# generator (test)       | 0.72 | 0.7156          | 0.0003
# discriminator (train)  | 0.72 | 0.6918          | 0.0253
# discriminator (test)   | 0.74 | 0.7288          | 0.0114
# Epoch 26/100
# 600/600 [==============================] - 35s 58ms/step
# Testing for epoch 26:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7736          | 0.0024
# generator (test)       | 0.81 | 0.8084          | 0.0003
# discriminator (train)  | 0.72 | 0.6910          | 0.0257
# discriminator (test)   | 0.73 | 0.7212          | 0.0111
# Epoch 27/100
# 600/600 [==============================] - 35s 58ms/step
# Testing for epoch 27:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7672          | 0.0018
# generator (test)       | 0.80 | 0.7958          | 0.0002
# discriminator (train)  | 0.72 | 0.6922          | 0.0236
# discriminator (test)   | 0.74 | 0.7269          | 0.0119
# Epoch 28/100
# 600/600 [==============================] - 34s 57ms/step
# Testing for epoch 28:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7710          | 0.0024
# generator (test)       | 0.85 | 0.8500          | 0.0009
# discriminator (train)  | 0.71 | 0.6896          | 0.0237
# discriminator (test)   | 0.72 | 0.7125          | 0.0117
# Epoch 29/100
# 600/600 [==============================] - 34s 57ms/step
# Testing for epoch 29:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7745          | 0.0018
# generator (test)       | 0.80 | 0.8009          | 0.0004
# discriminator (train)  | 0.71 | 0.6908          | 0.0226
# discriminator (test)   | 0.74 | 0.7244          | 0.0119
# Epoch 30/100
# 600/600 [==============================] - 34s 57ms/step
# Testing for epoch 30:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7661          | 0.0013
# generator (test)       | 0.81 | 0.8055          | 0.0001
# discriminator (train)  | 0.71 | 0.6921          | 0.0217
# discriminator (test)   | 0.76 | 0.7496          | 0.0115
# Epoch 31/100
# 600/600 [==============================] - 34s 57ms/step
# Testing for epoch 31:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7668          | 0.0013
# generator (test)       | 0.82 | 0.8188          | 0.0002
# discriminator (train)  | 0.71 | 0.6924          | 0.0203
# discriminator (test)   | 0.74 | 0.7254          | 0.0107
# Epoch 32/100
# 600/600 [==============================] - 35s 58ms/step
# Testing for epoch 32:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7730          | 0.0015
# generator (test)       | 0.74 | 0.7387          | 0.0004
# discriminator (train)  | 0.71 | 0.6916          | 0.0206
# discriminator (test)   | 0.73 | 0.7167          | 0.0115
# Epoch 33/100
# 600/600 [==============================] - 34s 57ms/step
# Testing for epoch 33:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7739          | 0.0014
# generator (test)       | 0.81 | 0.8101          | 0.0003
# discriminator (train)  | 0.71 | 0.6896          | 0.0202
# discriminator (test)   | 0.75 | 0.7376          | 0.0106
# Epoch 34/100
# 600/600 [==============================] - 35s 58ms/step
# Testing for epoch 34:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7752          | 0.0013
# generator (test)       | 0.79 | 0.7918          | 0.0001
# discriminator (train)  | 0.71 | 0.6898          | 0.0198
# discriminator (test)   | 0.74 | 0.7259          | 0.0106
# Epoch 35/100
# 600/600 [==============================] - 35s 58ms/step
# Testing for epoch 35:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7719          | 0.0012
# generator (test)       | 0.76 | 0.7644          | 0.0002
# discriminator (train)  | 0.71 | 0.6906          | 0.0190
# discriminator (test)   | 0.75 | 0.7352          | 0.0109
# Epoch 36/100
# 600/600 [==============================] - 35s 58ms/step
# Testing for epoch 36:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7710          | 0.0012
# generator (test)       | 0.79 | 0.7872          | 0.0001
# discriminator (train)  | 0.71 | 0.6906          | 0.0196
# discriminator (test)   | 0.73 | 0.7203          | 0.0107
# Epoch 37/100
# 600/600 [==============================] - 35s 58ms/step
# Testing for epoch 37:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7729          | 0.0010
# generator (test)       | 0.77 | 0.7692          | 0.0002
# discriminator (train)  | 0.71 | 0.6893          | 0.0182
# discriminator (test)   | 0.73 | 0.7193          | 0.0106
# Epoch 38/100
# 600/600 [==============================] - 35s 59ms/step
# Testing for epoch 38:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7741          | 0.0011
# generator (test)       | 0.83 | 0.8325          | 0.0005
# discriminator (train)  | 0.71 | 0.6896          | 0.0174
# discriminator (test)   | 0.74 | 0.7296          | 0.0106
# Epoch 39/100
# 600/600 [==============================] - 35s 59ms/step
# Testing for epoch 39:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7714          | 0.0010
# generator (test)       | 0.79 | 0.7888          | 0.0002
# discriminator (train)  | 0.71 | 0.6899          | 0.0169
# discriminator (test)   | 0.74 | 0.7261          | 0.0115
# Epoch 40/100
# 600/600 [==============================] - 35s 58ms/step
# Testing for epoch 40:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7705          | 0.0010
# generator (test)       | 0.77 | 0.7698          | 0.0001
# discriminator (train)  | 0.71 | 0.6900          | 0.0165
# discriminator (test)   | 0.71 | 0.7012          | 0.0109
# Epoch 41/100
# 600/600 [==============================] - 36s 59ms/step
# Testing for epoch 41:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7774          | 0.0011
# generator (test)       | 0.79 | 0.7910          | 0.0001
# discriminator (train)  | 0.71 | 0.6887          | 0.0168
# discriminator (test)   | 0.72 | 0.7087          | 0.0107
# Epoch 42/100
# 600/600 [==============================] - 36s 59ms/step
# Testing for epoch 42:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7721          | 0.0009
# generator (test)       | 0.81 | 0.8092          | 0.0001
# discriminator (train)  | 0.70 | 0.6889          | 0.0158
# discriminator (test)   | 0.72 | 0.7141          | 0.0109
# Epoch 43/100
# 600/600 [==============================] - 35s 59ms/step
# Testing for epoch 43:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7728          | 0.0010
# generator (test)       | 0.79 | 0.7938          | 0.0000
# discriminator (train)  | 0.70 | 0.6890          | 0.0156
# discriminator (test)   | 0.73 | 0.7134          | 0.0123
# Epoch 44/100
# 600/600 [==============================] - 36s 59ms/step
# Testing for epoch 44:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7709          | 0.0010
# generator (test)       | 0.83 | 0.8268          | 0.0001
# discriminator (train)  | 0.71 | 0.6893          | 0.0163
# discriminator (test)   | 0.72 | 0.7064          | 0.0104
# Epoch 45/100
# 600/600 [==============================] - 35s 59ms/step
# Testing for epoch 45:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7699          | 0.0008
# generator (test)       | 0.87 | 0.8705          | 0.0001
# discriminator (train)  | 0.71 | 0.6896          | 0.0159
# discriminator (test)   | 0.73 | 0.7171          | 0.0109
# Epoch 46/100
# 600/600 [==============================] - 35s 59ms/step
# Testing for epoch 46:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7709          | 0.0011
# generator (test)       | 0.84 | 0.8420          | 0.0001
# discriminator (train)  | 0.71 | 0.6894          | 0.0157
# discriminator (test)   | 0.73 | 0.7234          | 0.0112
# Epoch 47/100
# 600/600 [==============================] - 36s 60ms/step
# Testing for epoch 47:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7747          | 0.0008
# generator (test)       | 0.80 | 0.7969          | 0.0001
# discriminator (train)  | 0.70 | 0.6885          | 0.0152
# discriminator (test)   | 0.72 | 0.7064          | 0.0108
# Epoch 48/100
# 600/600 [==============================] - 36s 60ms/step
# Testing for epoch 48:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7733          | 0.0009
# generator (test)       | 0.84 | 0.8423          | 0.0001
# discriminator (train)  | 0.71 | 0.6892          | 0.0158
# discriminator (test)   | 0.72 | 0.7128          | 0.0105
# Epoch 49/100
# 600/600 [==============================] - 36s 60ms/step
# Testing for epoch 49:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7710          | 0.0009
# generator (test)       | 0.88 | 0.8833          | 0.0001
# discriminator (train)  | 0.70 | 0.6893          | 0.0146
# discriminator (test)   | 0.73 | 0.7225          | 0.0103
# Epoch 50/100
# 600/600 [==============================] - 36s 60ms/step
# Testing for epoch 50:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7716          | 0.0008
# generator (test)       | 0.80 | 0.7997          | 0.0001
# discriminator (train)  | 0.70 | 0.6899          | 0.0138
# discriminator (test)   | 0.72 | 0.7050          | 0.0101
# Epoch 51/100
# 600/600 [==============================] - 36s 61ms/step
# Testing for epoch 51:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7722          | 0.0008
# generator (test)       | 0.76 | 0.7644          | 0.0001
# discriminator (train)  | 0.70 | 0.6894          | 0.0151
# discriminator (test)   | 0.73 | 0.7175          | 0.0105
# Epoch 52/100
# 600/600 [==============================] - 37s 61ms/step
# Testing for epoch 52:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7696          | 0.0008
# generator (test)       | 0.82 | 0.8154          | 0.0001
# discriminator (train)  | 0.70 | 0.6897          | 0.0128
# discriminator (test)   | 0.70 | 0.6949          | 0.0097
# Epoch 53/100
# 600/600 [==============================] - 37s 61ms/step
# Testing for epoch 53:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7714          | 0.0007
# generator (test)       | 0.80 | 0.7970          | 0.0000
# discriminator (train)  | 0.70 | 0.6894          | 0.0135
# discriminator (test)   | 0.72 | 0.7085          | 0.0100
# Epoch 54/100
# 600/600 [==============================] - 37s 62ms/step
# Testing for epoch 54:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7684          | 0.0008
# generator (test)       | 0.86 | 0.8594          | 0.0000
# discriminator (train)  | 0.70 | 0.6894          | 0.0138
# discriminator (test)   | 0.73 | 0.7186          | 0.0104
# Epoch 55/100
# 600/600 [==============================] - 37s 62ms/step
# Testing for epoch 55:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7691          | 0.0009
# generator (test)       | 0.84 | 0.8368          | 0.0000
# discriminator (train)  | 0.70 | 0.6896          | 0.0130
# discriminator (test)   | 0.71 | 0.7022          | 0.0103
# Epoch 56/100
# 600/600 [==============================] - 37s 62ms/step
# Testing for epoch 56:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7697          | 0.0008
# generator (test)       | 0.81 | 0.8069          | 0.0000
# discriminator (train)  | 0.70 | 0.6895          | 0.0120
# discriminator (test)   | 0.72 | 0.7104          | 0.0108
# Epoch 57/100
# 600/600 [==============================] - 37s 62ms/step
# Testing for epoch 57:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7686          | 0.0009
# generator (test)       | 0.81 | 0.8072          | 0.0001
# discriminator (train)  | 0.70 | 0.6896          | 0.0135
# discriminator (test)   | 0.71 | 0.6976          | 0.0106
# Epoch 58/100
# 600/600 [==============================] - 37s 62ms/step
# Testing for epoch 58:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7680          | 0.0008
# generator (test)       | 0.81 | 0.8083          | 0.0000
# discriminator (train)  | 0.70 | 0.6896          | 0.0128
# discriminator (test)   | 0.72 | 0.7081          | 0.0108
# Epoch 59/100
# 600/600 [==============================] - 37s 62ms/step
# Testing for epoch 59:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7684          | 0.0008
# generator (test)       | 0.83 | 0.8293          | 0.0000
# discriminator (train)  | 0.70 | 0.6899          | 0.0124
# discriminator (test)   | 0.71 | 0.7033          | 0.0105
# Epoch 60/100
# 600/600 [==============================] - 37s 62ms/step
# Testing for epoch 60:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7681          | 0.0007
# generator (test)       | 0.82 | 0.8233          | 0.0000
# discriminator (train)  | 0.70 | 0.6891          | 0.0127
# discriminator (test)   | 0.72 | 0.7113          | 0.0104
# Epoch 61/100
# 600/600 [==============================] - 38s 63ms/step
# Testing for epoch 61:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7698          | 0.0007
# generator (test)       | 0.78 | 0.7822          | 0.0000
# discriminator (train)  | 0.70 | 0.6886          | 0.0110
# discriminator (test)   | 0.72 | 0.7042          | 0.0113
# Epoch 62/100
# 600/600 [==============================] - 38s 63ms/step
# Testing for epoch 62:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7689          | 0.0008
# generator (test)       | 0.85 | 0.8488          | 0.0001
# discriminator (train)  | 0.70 | 0.6896          | 0.0120
# discriminator (test)   | 0.72 | 0.7050          | 0.0106
# Epoch 63/100
# 600/600 [==============================] - 38s 63ms/step
# Testing for epoch 63:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7689          | 0.0008
# generator (test)       | 0.81 | 0.8101          | 0.0000
# discriminator (train)  | 0.70 | 0.6890          | 0.0113
# discriminator (test)   | 0.72 | 0.7035          | 0.0119
# Epoch 64/100
# 600/600 [==============================] - 38s 63ms/step
# Testing for epoch 64:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7690          | 0.0007
# generator (test)       | 0.81 | 0.8082          | 0.0000
# discriminator (train)  | 0.70 | 0.6884          | 0.0115
# discriminator (test)   | 0.71 | 0.7019          | 0.0110
# Epoch 65/100
# 600/600 [==============================] - 38s 63ms/step
# Testing for epoch 65:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7698          | 0.0008
# generator (test)       | 0.79 | 0.7885          | 0.0000
# discriminator (train)  | 0.70 | 0.6889          | 0.0117
# discriminator (test)   | 0.71 | 0.6985          | 0.0116
# Epoch 66/100
# 600/600 [==============================] - 38s 63ms/step
# Testing for epoch 66:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7698          | 0.0007
# generator (test)       | 0.83 | 0.8347          | 0.0000
# discriminator (train)  | 0.70 | 0.6890          | 0.0121
# discriminator (test)   | 0.72 | 0.7046          | 0.0107
# Epoch 67/100
# 600/600 [==============================] - 38s 64ms/step
# Testing for epoch 67:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7682          | 0.0009
# generator (test)       | 0.77 | 0.7661          | 0.0000
# discriminator (train)  | 0.70 | 0.6886          | 0.0113
# discriminator (test)   | 0.70 | 0.6928          | 0.0109
# Epoch 68/100
# 600/600 [==============================] - 38s 63ms/step
# Testing for epoch 68:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7672          | 0.0008
# generator (test)       | 0.80 | 0.7988          | 0.0001
# discriminator (train)  | 0.70 | 0.6896          | 0.0115
# discriminator (test)   | 0.71 | 0.7004          | 0.0104
# Epoch 69/100
# 600/600 [==============================] - 38s 63ms/step
# Testing for epoch 69:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7659          | 0.0007
# generator (test)       | 0.81 | 0.8097          | 0.0000
# discriminator (train)  | 0.70 | 0.6894          | 0.0110
# discriminator (test)   | 0.71 | 0.7005          | 0.0101
# Epoch 70/100
# 600/600 [==============================] - 40s 67ms/step
# Testing for epoch 70:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7682          | 0.0009
# generator (test)       | 0.83 | 0.8266          | 0.0001
# discriminator (train)  | 0.70 | 0.6885          | 0.0112
# discriminator (test)   | 0.71 | 0.6961          | 0.0109
# Epoch 71/100
# 600/600 [==============================] - 41s 69ms/step
# Testing for epoch 71:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7691          | 0.0008
# generator (test)       | 0.83 | 0.8328          | 0.0001
# discriminator (train)  | 0.70 | 0.6887          | 0.0102
# discriminator (test)   | 0.71 | 0.7033          | 0.0116
# Epoch 72/100
# 600/600 [==============================] - 41s 69ms/step
# Testing for epoch 72:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7675          | 0.0008
# generator (test)       | 0.79 | 0.7924          | 0.0000
# discriminator (train)  | 0.70 | 0.6895          | 0.0103
# discriminator (test)   | 0.71 | 0.6940          | 0.0113
# Epoch 73/100
# 600/600 [==============================] - 41s 69ms/step
# Testing for epoch 73:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7675          | 0.0008
# generator (test)       | 0.83 | 0.8300          | 0.0000
# discriminator (train)  | 0.70 | 0.6890          | 0.0109
# discriminator (test)   | 0.72 | 0.7051          | 0.0107
# Epoch 74/100
# 600/600 [==============================] - 39s 65ms/step
# Testing for epoch 74:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7682          | 0.0007
# generator (test)       | 0.79 | 0.7948          | 0.0000
# discriminator (train)  | 0.70 | 0.6886          | 0.0095
# discriminator (test)   | 0.70 | 0.6900          | 0.0100
# Epoch 75/100
# 600/600 [==============================] - 39s 64ms/step
# Testing for epoch 75:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7677          | 0.0008
# generator (test)       | 0.81 | 0.8070          | 0.0000
# discriminator (train)  | 0.70 | 0.6888          | 0.0104
# discriminator (test)   | 0.71 | 0.6969          | 0.0103
# Epoch 76/100
# 600/600 [==============================] - 39s 64ms/step
# Testing for epoch 76:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7672          | 0.0007
# generator (test)       | 0.83 | 0.8307          | 0.0000
# discriminator (train)  | 0.70 | 0.6890          | 0.0110
# discriminator (test)   | 0.71 | 0.6987          | 0.0110
# Epoch 77/100
# 600/600 [==============================] - 39s 65ms/step
# Testing for epoch 77:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7685          | 0.0007
# generator (test)       | 0.83 | 0.8280          | 0.0000
# discriminator (train)  | 0.70 | 0.6890          | 0.0105
# discriminator (test)   | 0.71 | 0.6990          | 0.0105
# Epoch 78/100
# 600/600 [==============================] - 39s 65ms/step
# Testing for epoch 78:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7676          | 0.0009
# generator (test)       | 0.79 | 0.7900          | 0.0000
# discriminator (train)  | 0.70 | 0.6893          | 0.0095
# discriminator (test)   | 0.70 | 0.6910          | 0.0110
# Epoch 79/100
# 600/600 [==============================] - 39s 65ms/step
# Testing for epoch 79:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7690          | 0.0006
# generator (test)       | 0.80 | 0.7985          | 0.0000
# discriminator (train)  | 0.70 | 0.6889          | 0.0098
# discriminator (test)   | 0.70 | 0.6937          | 0.0104
# Epoch 80/100
# 600/600 [==============================] - 39s 66ms/step
# Testing for epoch 80:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7660          | 0.0007
# generator (test)       | 0.79 | 0.7929          | 0.0000
# discriminator (train)  | 0.70 | 0.6889          | 0.0097
# discriminator (test)   | 0.71 | 0.6999          | 0.0101
# Epoch 81/100
# 600/600 [==============================] - 39s 65ms/step
# Testing for epoch 81:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7663          | 0.0007
# generator (test)       | 0.79 | 0.7926          | 0.0000
# discriminator (train)  | 0.70 | 0.6892          | 0.0101
# discriminator (test)   | 0.71 | 0.6958          | 0.0103
# Epoch 82/100
# 600/600 [==============================] - 39s 66ms/step
# Testing for epoch 82:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7651          | 0.0007
# generator (test)       | 0.82 | 0.8248          | 0.0000
# discriminator (train)  | 0.70 | 0.6895          | 0.0095
# discriminator (test)   | 0.72 | 0.7044          | 0.0108
# Epoch 83/100
# 600/600 [==============================] - 39s 66ms/step
# Testing for epoch 83:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7651          | 0.0008
# generator (test)       | 0.81 | 0.8116          | 0.0000
# discriminator (train)  | 0.70 | 0.6894          | 0.0094
# discriminator (test)   | 0.71 | 0.7053          | 0.0097
# Epoch 84/100
# 600/600 [==============================] - 40s 67ms/step
# Testing for epoch 84:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7646          | 0.0006
# generator (test)       | 0.78 | 0.7810          | 0.0000
# discriminator (train)  | 0.70 | 0.6900          | 0.0090
# discriminator (test)   | 0.70 | 0.6935          | 0.0111
# Epoch 85/100
# 600/600 [==============================] - 41s 68ms/step
# Testing for epoch 85:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7640          | 0.0006
# generator (test)       | 0.81 | 0.8084          | 0.0000
# discriminator (train)  | 0.70 | 0.6898          | 0.0090
# discriminator (test)   | 0.72 | 0.7059          | 0.0112
# Epoch 86/100
# 600/600 [==============================] - 42s 71ms/step
# Testing for epoch 86:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7633          | 0.0007
# generator (test)       | 0.80 | 0.7974          | 0.0000
# discriminator (train)  | 0.70 | 0.6898          | 0.0098
# discriminator (test)   | 0.71 | 0.7011          | 0.0104
# Epoch 87/100
# 600/600 [==============================] - 42s 70ms/step
# Testing for epoch 87:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7639          | 0.0007
# generator (test)       | 0.79 | 0.7923          | 0.0000
# discriminator (train)  | 0.70 | 0.6900          | 0.0101
# discriminator (test)   | 0.71 | 0.6984          | 0.0099
# Epoch 88/100
# 600/600 [==============================] - 43s 71ms/step
# Testing for epoch 88:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7639          | 0.0006
# generator (test)       | 0.79 | 0.7891          | 0.0000
# discriminator (train)  | 0.70 | 0.6902          | 0.0085
# discriminator (test)   | 0.72 | 0.7045          | 0.0111
# Epoch 89/100
# 600/600 [==============================] - 40s 67ms/step
# Testing for epoch 89:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7629          | 0.0006
# generator (test)       | 0.79 | 0.7942          | 0.0000
# discriminator (train)  | 0.70 | 0.6901          | 0.0095
# discriminator (test)   | 0.72 | 0.7071          | 0.0102
# Epoch 90/100
# 600/600 [==============================] - 40s 67ms/step
# Testing for epoch 90:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7631          | 0.0006
# generator (test)       | 0.81 | 0.8077          | 0.0000
# discriminator (train)  | 0.70 | 0.6901          | 0.0087
# discriminator (test)   | 0.72 | 0.7079          | 0.0095
# Epoch 91/100
# 600/600 [==============================] - 40s 67ms/step
# Testing for epoch 91:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7631          | 0.0006
# generator (test)       | 0.79 | 0.7913          | 0.0000
# discriminator (train)  | 0.70 | 0.6905          | 0.0098
# discriminator (test)   | 0.71 | 0.7000          | 0.0098
# Epoch 92/100
# 600/600 [==============================] - 40s 66ms/step
# Testing for epoch 92:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7623          | 0.0007
# generator (test)       | 0.85 | 0.8542          | 0.0000
# discriminator (train)  | 0.70 | 0.6897          | 0.0091
# discriminator (test)   | 0.73 | 0.7173          | 0.0106
# Epoch 93/100
# 600/600 [==============================] - 40s 67ms/step
# Testing for epoch 93:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7629          | 0.0007
# generator (test)       | 0.83 | 0.8253          | 0.0000
# discriminator (train)  | 0.70 | 0.6902          | 0.0092
# discriminator (test)   | 0.71 | 0.7037          | 0.0102
# Epoch 94/100
# 600/600 [==============================] - 40s 66ms/step
# Testing for epoch 94:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7610          | 0.0006
# generator (test)       | 0.78 | 0.7827          | 0.0000
# discriminator (train)  | 0.70 | 0.6901          | 0.0087
# discriminator (test)   | 0.72 | 0.7081          | 0.0100
# Epoch 95/100
# 600/600 [==============================] - 40s 67ms/step
# Testing for epoch 95:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7620          | 0.0009
# generator (test)       | 0.79 | 0.7929          | 0.0000
# discriminator (train)  | 0.70 | 0.6903          | 0.0094
# discriminator (test)   | 0.73 | 0.7168          | 0.0105
# Epoch 96/100
# 600/600 [==============================] - 40s 66ms/step
# Testing for epoch 96:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7608          | 0.0007
# generator (test)       | 0.85 | 0.8475          | 0.0000
# discriminator (train)  | 0.70 | 0.6907          | 0.0090
# discriminator (test)   | 0.72 | 0.7077          | 0.0102
# Epoch 97/100
# 600/600 [==============================] - 39s 66ms/step
# Testing for epoch 97:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7609          | 0.0007
# generator (test)       | 0.83 | 0.8303          | 0.0000
# discriminator (train)  | 0.70 | 0.6910          | 0.0085
# discriminator (test)   | 0.73 | 0.7147          | 0.0112
# Epoch 98/100
# 600/600 [==============================] - 40s 66ms/step
# Testing for epoch 98:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7603          | 0.0008
# generator (test)       | 0.84 | 0.8403          | 0.0001
# discriminator (train)  | 0.70 | 0.6914          | 0.0087
# discriminator (test)   | 0.73 | 0.7156          | 0.0112
# Epoch 99/100
# 600/600 [==============================] - 40s 66ms/step
# Testing for epoch 99:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7595          | 0.0007
# generator (test)       | 0.84 | 0.8440          | 0.0002
# discriminator (train)  | 0.70 | 0.6908          | 0.0091
# discriminator (test)   | 0.72 | 0.7145          | 0.0103
# Epoch 100/100
# 600/600 [==============================] - 40s 67ms/step
# Testing for epoch 100:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7599          | 0.0007
# generator (test)       | 0.90 | 0.9034          | 0.0001
# discriminator (train)  | 0.70 | 0.6910          | 0.0078
# discriminator (test)   | 0.73 | 0.7211          | 0.0098
